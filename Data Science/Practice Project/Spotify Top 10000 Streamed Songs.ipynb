# %% [markdown]
# # Analyzing [Spotify Top 10000 Streamed Songs](https://www.kaggle.com/datasets/rakkesharv/spotify-top-10000-streamed-songs)

# %% [markdown]
# ## About Dataset
# One of the biggest music streaming platform, but who's the biggest streamed here? This dataset which is webscrapped and accumulated all the stream metrics of each artist and their respective songs.
#
# - Position - Spotify Ranking
# - Artist Name - Artist Name
# - Song Name - Song Name
# - Days - No of days since the release of the song (Updated)
# - Top 10 (xTimes) - No of times inside top 10
# - Peak Position - Peak position attained
# - Peak Position (xTimes) - No of times Peak position attained
# - Peak Streams - Total no of streams during Peak position
# - **Total Streams**- Total song streams

# %% [markdown]
# First, let's read the database

# %%
import pandas as pd
spotify_df = pd.read_csv('database/Spotify_final_dataset.csv')

# %%
spotify_df
# Out:
#        Position         Artist Name  \
# 0             1        Post Malone
# 1             2         Juice WRLD
# 2             3       Lil Uzi Vert
# 3             4            J. Cole
# 4             5        Post Malone
# ...         ...                 ...
# 11079     11080     The Band Perry
# 11080     11081  Justin Timberlake
# 11081     11082      Mike WiLL Made
# 11082     11083          The Vamps
# 11083     11084                 JAY
#
#                                         Song Name  Days  Top 10 (xTimes)  \
# 0      Sunflower  SpiderMan: Into the SpiderVerse  1506            302.0
# 1                                    Lucid Dreams  1673            178.0
# 2                                   XO TOUR Llif3  1853            212.0
# 3                                  No Role Modelz  2547              6.0
# 4                                        rockstar  1223            186.0
# ...                                           ...   ...              ...
# ...

# %% [markdown]
# **Q1. What is the top 10 med Song in Spotify?**

# %%
top_10_songs=spotify_df.head(10)
top_10_songs
# Out:
#    Position    Artist Name                                   Song Name  Days  \
# 0         1   Post Malone   Sunflower  SpiderMan: Into the SpiderVerse  1506
# 1         2    Juice WRLD                                 Lucid Dreams  1673
# 2         3  Lil Uzi Vert                                XO TOUR Llif3  1853
# 3         4       J. Cole                               No Role Modelz  2547
# 4         5   Post Malone                                     rockstar  1223
# 5         6  Travis Scott                                   goosebumps  1995
# 6         7    The Weeknd                              Blinding Lights  1100
# 7         8  XXXTENTACION                               Jocelyn Flores  1673
# 8         9  XXXTENTACION                                         SAD!  1217
# 9        10    Juice WRLD                       All Girls Are The Same  1681
#
#    Top 10 (xTimes)  Peak Position Peak Position (xTimes)  Peak Streams  \
# ...

# %% [markdown]
# **Q2. How many unique singers are there in the Top 10000 streamed songs?**

# %%
num_of_unique_artists = spotify_df['Artist Name'].unique().shape[0]
print("There are %d unique artists in the Top 10,000 streamed spotify songs."%num_of_unique_artists)
# Out:
# There are 1612 unique artists in the Top 10,000 streamed spotify songs.

# %% [markdown]
# **Q3. Who are the Artists that has the most numbers of songs in the Top 10000**

# %%
top_hit_artists_df = spotify_df.groupby('Artist Name').count().sort_values('Song Name',ascending=False)
top_hit_artists_df
# Out:
#                Position  Song Name  Days  Top 10 (xTimes)  Peak Position  \
# Artist Name
# Drake               208        208   208              208            208
# Future              190        190   190              190            190
# Taylor Swift        172        172   172              172            172
# Logic               120        120   120              120            120
# Trippie Redd        114        114   114              114            114
# ...                 ...        ...   ...              ...            ...
# Etta James            1          1     1                1              1
# Jenny Duncan          1          0     1                1              1
# Dj Ozuna              1          0     1                1              1
# Amy Kaylee            1          0     1                1              1
# Daniel Marcy          1          0     1                1              1
#
#                Peak Position (xTimes)  Peak Streams  Total Streams
# ...

# %% [markdown]
# The top 10 artists that has the most numbers of songs in the database are:

# %%
top_10hit_artists = top_hit_artists_df.head(10)
top_10hit_artists
# Out:
#                              Position  Song Name  Days  Top 10 (xTimes)  \
# Artist Name
# Drake                             208        208   208              208
# Future                            190        190   190              190
# Taylor Swift                      172        172   172              172
# Logic                             120        120   120              120
# Trippie Redd                      114        114   114              114
# Lil Baby                          105        105   105              105
# Kanye West                         91         91    91               91
# Juice WRLD                         91         91    91               91
# The Weeknd                         90         90    90               90
# YoungBoy Never Broke Again         89         89    89               89
#
#                              Peak Position  Peak Position (xTimes)  \
# Artist Name
# Drake                                  208                     208
# ...

# %%
top_5hit_artists = top_hit_artists_df.head(5)
top_5hit_artists
# Out:
#                Position  Song Name  Days  Top 10 (xTimes)  Peak Position  \
# Artist Name
# Drake               208        208   208              208            208
# Future              190        190   190              190            190
# Taylor Swift        172        172   172              172            172
# Logic               120        120   120              120            120
# Trippie Redd        114        114   114              114            114
#
#                Peak Position (xTimes)  Peak Streams  Total Streams
# Artist Name
# Drake                             208           208            208
# Future                            190           190            190
# Taylor Swift                      172           172            172
# Logic                             120           120            120
# Trippie Redd                      114           114            114

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

top_5hit_artists.plot(marker="o",color="blue")

sns.set_style("whitegrid")
plt.title("Artists with most numbers of songs in the Top 10000")
plt.ylabel('Number of Songs')
plt.legend(["Number of Songs in the Top 10000 Streamed Songs"])

# %% [markdown]
# **Q4. Which songs have the most number of times in the Top 10?**

# %%
always_in_top_10 = spotify_df.sort_values('Top 10 (xTimes)', ascending=False)
always_in_top_10
# Out:
#        Position     Artist Name                                   Song Name  \
# 0             1    Post Malone   Sunflower  SpiderMan: Into the SpiderVerse
# 29           30  The Kid LAROI                                         Stay
# 45           46      Lil Nas X                                INDUSTRY BABY
# 16           17  Glass Animals                                   Heat Waves
# 6             7     The Weeknd                              Blinding Lights
# ...         ...             ...                                         ...
# 4497       4498     Kanye West                                   Low Lights
# 4498       4499       2 Chainz                                   Big Amount
# 4499       4500          Logic                                  Hit My Line
# 4500       4501          6LACK                         Balenciaga Challenge
# 11083     11084             JAY                               Z  Holy Grail
#
# ...

# %% [markdown]
# The top 10 songs that have the most number of times in the Top 10 are the following:

# %%
top_hit_songs=always_in_top_10.head(5)
top_hit_songs
# Out:
#     Position     Artist Name                                   Song Name  \
# 0          1    Post Malone   Sunflower  SpiderMan: Into the SpiderVerse
# 29        30  The Kid LAROI                                         Stay
# 45        46      Lil Nas X                                INDUSTRY BABY
# 16        17  Glass Animals                                   Heat Waves
# 6          7     The Weeknd                              Blinding Lights
#
#     Days  Top 10 (xTimes)  Peak Position Peak Position (xTimes)  Peak Streams  \
# 0   1506            302.0              1                  (x29)       2118242
# 29   531            271.0              1                  (x45)       2345292
# 45   472            267.0              1                  (x42)       2492612
# 16   763            248.0              1                  (x34)       1230046
# 6   1100            233.0              1                  (x11)       2355059
#
#     Total Streams
# 0       883369738
# 29      426712325
# ...

# %%
plt.rcParams['font.size'] = 14
plt.rcParams['figure.figsize'] = (9, 5)
plt.rcParams['figure.facecolor'] = '#00000000'

# %%
top_hit_songs.plot('Song Name','Top 10 (xTimes)',marker="o")
# Out:
# <AxesSubplot: xlabel='Song Name'>

# %% [markdown]
# **Q5. What Top 1 songs have the most streams??**

# %%
top1_top_stream = spotify_df[spotify_df['Peak Position']==1].sort_values('Total Streams',ascending=False)
top1_top_stream.head(15)
# Out:
#     Position      Artist Name                                   Song Name  \
# 0          1     Post Malone   Sunflower  SpiderMan: Into the SpiderVerse
# 1          2      Juice WRLD                                 Lucid Dreams
# 2          3    Lil Uzi Vert                                XO TOUR Llif3
# 4          5     Post Malone                                     rockstar
# 6          7      The Weeknd                              Blinding Lights
# 8          9    XXXTENTACION                                         SAD!
# 10        11  Kendrick Lamar                                      HUMBLE.
# 11        12     Post Malone                                      Circles
# 12        13    Travis Scott                                   SICKO MODE
# 13        14        Lil Baby             Drip Too Hard (Lil Baby & Gunna)
# 16        17   Glass Animals                                   Heat Waves
# 17        18           Drake                                   God's Plan
# ...
